# %% [markdown]
# <a href="https://colab.research.google.com/github/CrazyCyberbug/Audio-Library/blob/main/Untitled57.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## IIT-M   deep learning practice
#
# Huggingface is a library that can abstract away  most of the complexities in the model training process
#
# here's some popular libraries that you would be using very frequently
# The library is built on PyTorch
#
#
# * `tokenizer`
# * `datasets`
# * `transformers`
# * `evaluate`
# * `optimum` - optimize the inference for specific hardware
# * `accelarate` - optimize model on gpus
# * `peft` - parameter effecient fine tuning
# * `bitsandbytes` - quantize the models
#
# so everything that you would  need  to implement /use is available in form of neatly packaged libraries

# %%
import datasets

imdb_dataset = datasets.load_dataset("imdb")
print(imdb_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })

# %% [markdown]
# The dataset is wrapped in  `DatasetDict` class. We'll inspect only the train split. You can access this just like a regular dict.T

# %%
train_split = imdb_dataset['train']
train_split
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 25000
# })

# %% [markdown]
# This is now a `Dataset` object. Additionally you can use the pop to remove any entry just like in dictionary.

# %%
imdb_dataset.pop('unsupervised')
imdb_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
# })

# %% [markdown]
# Instead of downloading the dataset and them removing parts you do not like you could directly download only the specific part using the `split` arg
